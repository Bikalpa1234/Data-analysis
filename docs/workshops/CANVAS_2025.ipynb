# %% [markdown]
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/opengeos/geoai/blob/main/docs/workshops/CANVAS_2025.ipynb)
#
# **Open Source Pipeline to Integrate Drone and Satellite Geospatial Data Products for Agricultural Applications**
#
# This notebook is designed for workshop presented at the [CANAVS 2025 Conference](https://www.sciencesocieties.org/canvas?q=canvas/) on November 10, 2025.
#
# -   Registration: <https://scisoc.confex.com/scisoc/2025am/meetingapp.cgi/Session/27796>
# -   Notebook: <https://opengeoai.org/workshops/CANVAS_2025>
# -   Leafmap: <https://leafmap.org>
# -   Samgeo: <https://samgeo.gishub.org>
# -   GeoAI: <https://opengeoai.org>
# -   Data to Science (D2S): <https://ps2.d2s.org>
# -   D2S Python API: <https://py.d2s.org>
#
# ## Introduction
#
# Recent advances in drone technology have revolutionized the remote sensing community by providing means to collect fine spatial and high temporal resolutions at affordable costs. As people are gaining access to increasingly larger volumes of drone and satellite geospatial data products, there is a growing need to extract relevant information from the vast amount of freely available geospatial data. However, the lack of specialized software packages tailored for processing such data makes it challenging to develop transdisciplinary research collaboration around them. This workshop aims to bridge the gap between big geospatial data and research scientists by providing training on an open-source online platform for managing big drone data known as Data to Science.
#
# ## Agenda
#
# The main topics to be covered in this workshop include:
#
# * Create interactive maps using leafmap
# * Visualize drone imagery from D2S
# * Automated segmentation of drone imagery using SAMGeo
# * Training a U-Net model for tree segmentation
#
# ## Environment setup
#
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/opengeos/geoai/blob/main/docs/workshops/CANVAS_2025.ipynb)
#
#
# ### Change runtime type to GPU
#
# To speed up the processing, you can change the Colab runtime type to GPU. Go to the "Runtime" menu, select "Change runtime type", and choose "T4 GPU" from the "Hardware accelerator" dropdown menu.
#
# ![image](https://github.com/user-attachments/assets/e92d2a19-0555-456d-b4be-36680c0af09f)
#
#
# ### Install packages
#
# Uncomment the following code to install the required packages.

# %%
# %pip install -U "leafmap[raster]" "segment-geospatial[samgeo2]" geoai-py
# Out:
# Requirement already satisfied: geoai-py in /usr/local/lib/python3.12/dist-packages (0.18.1)
# Requirement already satisfied: leafmap[raster] in /usr/local/lib/python3.12/dist-packages (0.57.2)
# Requirement already satisfied: segment-geospatial[samgeo2] in /usr/local/lib/python3.12/dist-packages (0.13.0)
# Requirement already satisfied: anywidget in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (0.9.18)
# Requirement already satisfied: bqplot in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (0.12.45)
# Requirement already satisfied: duckdb>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (1.4.1)
# Requirement already satisfied: folium in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (0.20.0)
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (5.2.0)
# Requirement already satisfied: geojson in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (3.2.0)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (1.1.1)
# Requirement already satisfied: ipyevents in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (2.0.4)
# Requirement already satisfied: ipyfilechooser in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (0.6.0)
# Requirement already satisfied: ipyleaflet in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (0.20.0)
# Requirement already satisfied: ipyvuetify in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (1.11.3)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (7.7.1)
# Requirement already satisfied: maplibre in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (0.3.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (2.2.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (5.24.1)
# Requirement already satisfied: pystac-client in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (0.9.0)
# Requirement already satisfied: python-box in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (7.3.2)
# Requirement already satisfied: scooby in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (0.11.0)
# Requirement already satisfied: whiteboxgui in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (2.3.0)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (2025.10.0)
# Requirement already satisfied: localtileserver>=0.10.6 in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (0.10.6)
# Requirement already satisfied: jupyter-server-proxy in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (4.4.0)
# Requirement already satisfied: rio-cogeo in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (6.0.0)
# Requirement already satisfied: rioxarray in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (0.20.0)
# Requirement already satisfied: netcdf4 in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (1.7.3)
# Requirement already satisfied: d2spy in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (0.4.0)
# Requirement already satisfied: h5netcdf in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (1.7.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (3.15.1)
# Requirement already satisfied: opera-utils in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (0.25.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (5.9.5)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo2]) (0.36.0)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo2]) (4.12.0.88)
# Requirement already satisfied: patool in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo2]) (4.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo2]) (11.3.0)
# Requirement already satisfied: pyproj in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo2]) (3.7.2)
# Requirement already satisfied: rasterio in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo2]) (1.4.3)
# Requirement already satisfied: segment_anything in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo2]) (1.0)
# Requirement already satisfied: shapely in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo2]) (2.1.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo2]) (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo2]) (0.23.0+cu126)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo2]) (4.67.1)
# Requirement already satisfied: sam2 in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo2]) (1.1.0)
# Requirement already satisfied: xarray in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo2]) (2025.10.1)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo2]) (0.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo2]) (1.16.3)
# Requirement already satisfied: albumentations in /usr/local/lib/python3.12/dist-packages (from geoai-py) (2.0.8)
# Requirement already satisfied: buildingregulariser in /usr/local/lib/python3.12/dist-packages (from geoai-py) (0.2.4)
# Requirement already satisfied: contextily in /usr/local/lib/python3.12/dist-packages (from geoai-py) (1.6.2)
# Requirement already satisfied: datasets>=3.0 in /usr/local/lib/python3.12/dist-packages (from geoai-py) (4.0.0)
# Requirement already satisfied: ever-beta in /usr/local/lib/python3.12/dist-packages (from geoai-py) (0.5.3)
# Requirement already satisfied: mapclassify in /usr/local/lib/python3.12/dist-packages (from geoai-py) (2.10.0)
# Requirement already satisfied: overturemaps in /usr/local/lib/python3.12/dist-packages (from geoai-py) (0.17.0)
# Requirement already satisfied: planetary-computer in /usr/local/lib/python3.12/dist-packages (from geoai-py) (1.0.0)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.12/dist-packages (from geoai-py) (18.1.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from geoai-py) (1.6.1)
# Requirement already satisfied: timm in /usr/local/lib/python3.12/dist-packages (from geoai-py) (1.0.21)
# Requirement already satisfied: tokenizers>=0.22.1 in /usr/local/lib/python3.12/dist-packages (from geoai-py) (0.22.1)
# Requirement already satisfied: torchgeo in /usr/local/lib/python3.12/dist-packages (from geoai-py) (0.7.2)
# Requirement already satisfied: torchinfo in /usr/local/lib/python3.12/dist-packages (from geoai-py) (1.8.0)
# Requirement already satisfied: transformers>=4.57.1 in /usr/local/lib/python3.12/dist-packages (from geoai-py) (4.57.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0->geoai-py) (3.20.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0->geoai-py) (0.3.8)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0->geoai-py) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0->geoai-py) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0->geoai-py) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0->geoai-py) (2025.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0->geoai-py) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0->geoai-py) (6.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->segment-geospatial[samgeo2]) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->segment-geospatial[samgeo2]) (1.2.0)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from localtileserver>=0.10.6->leafmap[raster]) (8.3.0)
# Requirement already satisfied: flask<4,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from localtileserver>=0.10.6->leafmap[raster]) (3.1.2)
# Requirement already satisfied: Flask-Caching in /usr/local/lib/python3.12/dist-packages (from localtileserver>=0.10.6->leafmap[raster]) (2.3.1)
# Requirement already satisfied: flask-cors in /usr/local/lib/python3.12/dist-packages (from localtileserver>=0.10.6->leafmap[raster]) (6.0.1)
# Requirement already satisfied: flask-restx>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from localtileserver>=0.10.6->leafmap[raster]) (1.3.2)
# Requirement already satisfied: rio-tiler in /usr/local/lib/python3.12/dist-packages (from localtileserver>=0.10.6->leafmap[raster]) (7.9.2)
# Requirement already satisfied: server-thread in /usr/local/lib/python3.12/dist-packages (from localtileserver>=0.10.6->leafmap[raster]) (0.3.0)
# Requirement already satisfied: werkzeug in /usr/local/lib/python3.12/dist-packages (from localtileserver>=0.10.6->leafmap[raster]) (3.1.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.57.1->geoai-py) (2024.11.6)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.57.1->geoai-py) (0.6.2)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.12/dist-packages (from albumentations->geoai-py) (2.11.10)
# Requirement already satisfied: albucore==0.0.24 in /usr/local/lib/python3.12/dist-packages (from albumentations->geoai-py) (0.0.24)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations->geoai-py) (4.2.3)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations->geoai-py) (6.5.3)
# Requirement already satisfied: psygnal>=0.8.1 in /usr/local/lib/python3.12/dist-packages (from anywidget->leafmap[raster]) (0.15.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap[raster]) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap[raster]) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap[raster]) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap[raster]) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap[raster]) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap[raster]) (3.0.16)
# Requirement already satisfied: traittypes>=0.0.6 in /usr/local/lib/python3.12/dist-packages (from bqplot->leafmap[raster]) (0.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->leafmap[raster]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->leafmap[raster]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->leafmap[raster]) (2025.2)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas->leafmap[raster]) (0.11.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from pyproj->segment-geospatial[samgeo2]) (2025.10.5)
# Requirement already satisfied: geopy in /usr/local/lib/python3.12/dist-packages (from contextily->geoai-py) (2.4.1)
# Requirement already satisfied: mercantile in /usr/local/lib/python3.12/dist-packages (from contextily->geoai-py) (1.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from contextily->geoai-py) (1.5.2)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.12/dist-packages (from ever-beta->geoai-py) (3.16.0)
# Requirement already satisfied: tensorboard>=1.14 in /usr/local/lib/python3.12/dist-packages (from ever-beta->geoai-py) (2.19.0)
# Requirement already satisfied: tifffile in /usr/local/lib/python3.12/dist-packages (from ever-beta->geoai-py) (2025.10.16)
# Requirement already satisfied: wandb in /usr/local/lib/python3.12/dist-packages (from ever-beta->geoai-py) (0.22.3)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from ever-beta->geoai-py) (0.8.1)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from folium->leafmap[raster]) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.12/dist-packages (from folium->leafmap[raster]) (3.1.6)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown->leafmap[raster]) (4.13.5)
# Requirement already satisfied: jupyter-leaflet<0.21,>=0.20 in /usr/local/lib/python3.12/dist-packages (from ipyleaflet->leafmap[raster]) (0.20.0)
# Requirement already satisfied: ipyvue<2,>=1.7 in /usr/local/lib/python3.12/dist-packages (from ipyvuetify->leafmap[raster]) (1.11.3)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from jupyter-server-proxy->leafmap[raster]) (3.13.2)
# Requirement already satisfied: jupyter-server>=1.24.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server-proxy->leafmap[raster]) (2.14.0)
# Requirement already satisfied: simpervisor>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server-proxy->leafmap[raster]) (1.0.0)
# Requirement already satisfied: tornado>=6.1.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server-proxy->leafmap[raster]) (6.5.1)
# Requirement already satisfied: networkx>=3.2 in /usr/local/lib/python3.12/dist-packages (from mapclassify->geoai-py) (3.5)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->geoai-py) (3.6.0)
# Requirement already satisfied: eval-type-backport in /usr/local/lib/python3.12/dist-packages (from maplibre->leafmap[raster]) (0.2.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->leafmap[raster]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->leafmap[raster]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->leafmap[raster]) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->leafmap[raster]) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->leafmap[raster]) (3.2.5)
# Requirement already satisfied: cftime in /usr/local/lib/python3.12/dist-packages (from netcdf4->leafmap[raster]) (1.6.5)
# Requirement already satisfied: pooch>=1.7 in /usr/local/lib/python3.12/dist-packages (from opera-utils->leafmap[raster]) (1.8.2)
# Requirement already satisfied: tyro>=0.9 in /usr/local/lib/python3.12/dist-packages (from opera-utils->leafmap[raster]) (0.9.35)
# Requirement already satisfied: pystac>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from planetary-computer->geoai-py) (1.14.1)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from planetary-computer->geoai-py) (1.2.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->leafmap[raster]) (8.5.0)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from rasterio->segment-geospatial[samgeo2]) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio->segment-geospatial[samgeo2]) (25.4.0)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from rasterio->segment-geospatial[samgeo2]) (0.7.2)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.12/dist-packages (from rasterio->segment-geospatial[samgeo2]) (1.1.1.2)
# Requirement already satisfied: morecantile<7.0,>=5.0 in /usr/local/lib/python3.12/dist-packages (from rio-cogeo->leafmap[raster]) (6.2.0)
# Requirement already satisfied: hydra-core>=1.3.2 in /usr/local/lib/python3.12/dist-packages (from sam2->segment-geospatial[samgeo2]) (1.3.2)
# Requirement already satisfied: iopath>=0.1.10 in /usr/local/lib/python3.12/dist-packages (from sam2->segment-geospatial[samgeo2]) (0.1.10)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->segment-geospatial[samgeo2]) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->segment-geospatial[samgeo2]) (1.13.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->segment-geospatial[samgeo2]) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->segment-geospatial[samgeo2]) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->segment-geospatial[samgeo2]) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->segment-geospatial[samgeo2]) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->segment-geospatial[samgeo2]) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->segment-geospatial[samgeo2]) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->segment-geospatial[samgeo2]) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->segment-geospatial[samgeo2]) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->segment-geospatial[samgeo2]) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->segment-geospatial[samgeo2]) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch->segment-geospatial[samgeo2]) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->segment-geospatial[samgeo2]) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->segment-geospatial[samgeo2]) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->segment-geospatial[samgeo2]) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch->segment-geospatial[samgeo2]) (3.4.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->segment-geospatial[samgeo2]) (2.37.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->segment-geospatial[samgeo2]) (0.4)
# Requirement already satisfied: fiona>=1.8.22 in /usr/local/lib/python3.12/dist-packages (from torchgeo->geoai-py) (1.10.1)
# Requirement already satisfied: jsonargparse>=4.25 in /usr/local/lib/python3.12/dist-packages (from jsonargparse[signatures]>=4.25->torchgeo->geoai-py) (4.42.0)
# Requirement already satisfied: kornia>=0.7.4 in /usr/local/lib/python3.12/dist-packages (from torchgeo->geoai-py) (0.8.2)
# Requirement already satisfied: lightly!=1.4.26,>=1.4.5 in /usr/local/lib/python3.12/dist-packages (from torchgeo->geoai-py) (1.5.22)
# Requirement already satisfied: lightning!=2.3.*,!=2.5.0,!=2.5.5,>=2 in /usr/local/lib/python3.12/dist-packages (from torchgeo->geoai-py) (2.5.6)
# Requirement already satisfied: rtree>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from torchgeo->geoai-py) (1.4.1)
# Requirement already satisfied: segmentation-models-pytorch>=0.5 in /usr/local/lib/python3.12/dist-packages (from torchgeo->geoai-py) (0.5.0)
# Requirement already satisfied: torchmetrics>=1.2 in /usr/local/lib/python3.12/dist-packages (from torchgeo->geoai-py) (1.8.2)
# Requirement already satisfied: ipytree in /usr/local/lib/python3.12/dist-packages (from whiteboxgui->leafmap[raster]) (0.2.2)
# Requirement already satisfied: whitebox in /usr/local/lib/python3.12/dist-packages (from whiteboxgui->leafmap[raster]) (2.3.6)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from flask<4,>=2.0.0->localtileserver>=0.10.6->leafmap[raster]) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from flask<4,>=2.0.0->localtileserver>=0.10.6->leafmap[raster]) (2.2.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from flask<4,>=2.0.0->localtileserver>=0.10.6->leafmap[raster]) (3.0.3)
# Requirement already satisfied: aniso8601>=0.82 in /usr/local/lib/python3.12/dist-packages (from flask-restx>=1.3.0->localtileserver>=0.10.6->leafmap[raster]) (10.0.1)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.12/dist-packages (from flask-restx>=1.3.0->localtileserver>=0.10.6->leafmap[raster]) (4.25.1)
# Requirement already satisfied: referencing in /usr/local/lib/python3.12/dist-packages (from flask-restx>=1.3.0->localtileserver>=0.10.6->leafmap[raster]) (0.37.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.12/dist-packages (from flask-restx>=1.3.0->localtileserver>=0.10.6->leafmap[raster]) (6.5.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jupyter-server-proxy->leafmap[raster]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jupyter-server-proxy->leafmap[raster]) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jupyter-server-proxy->leafmap[raster]) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jupyter-server-proxy->leafmap[raster]) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jupyter-server-proxy->leafmap[raster]) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jupyter-server-proxy->leafmap[raster]) (1.22.0)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in /usr/local/lib/python3.12/dist-packages (from hydra-core>=1.3.2->sam2->segment-geospatial[samgeo2]) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from hydra-core>=1.3.2->sam2->segment-geospatial[samgeo2]) (4.9.3)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.12/dist-packages (from iopath>=0.1.10->sam2->segment-geospatial[samgeo2]) (3.2.0)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap[raster]) (1.8.15)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap[raster]) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap[raster]) (0.2.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap[raster]) (1.6.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap[raster]) (26.2.1)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap[raster]) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap[raster]) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap[raster]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap[raster]) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap[raster]) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap[raster]) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap[raster]) (4.9.0)
# Requirement already satisfied: docstring-parser>=0.17 in /usr/local/lib/python3.12/dist-packages (from jsonargparse[signatures]>=4.25->torchgeo->geoai-py) (0.17.0)
# Requirement already satisfied: typeshed-client>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from jsonargparse[signatures]>=4.25->torchgeo->geoai-py) (2.8.2)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (4.11.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (25.1.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (5.9.1)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (0.23.1)
# Requirement already satisfied: send2trash>=1.8.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (1.9.0)
# Requirement already satisfied: kornia_rs>=0.1.9 in /usr/local/lib/python3.12/dist-packages (from kornia>=0.7.4->torchgeo->geoai-py) (0.1.10)
# Requirement already satisfied: lightly_utils~=0.0.0 in /usr/local/lib/python3.12/dist-packages (from lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py) (0.0.2)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.12/dist-packages (from lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py) (1.17.0)
# Requirement already satisfied: pytorch_lightning>=1.0.4 in /usr/local/lib/python3.12/dist-packages (from lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py) (2.5.6)
# Requirement already satisfied: urllib3>=1.25.3 in /usr/local/lib/python3.12/dist-packages (from lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py) (2.5.0)
# Requirement already satisfied: aenum>=3.1.11 in /usr/local/lib/python3.12/dist-packages (from lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py) (3.1.16)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from lightning!=2.3.*,!=2.5.0,!=2.5.5,>=2->torchgeo->geoai-py) (0.15.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.7->opera-utils->leafmap[raster]) (4.5.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations->geoai-py) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations->geoai-py) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations->geoai-py) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=3.0->geoai-py) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=3.0->geoai-py) (3.11)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->segment-geospatial[samgeo2]) (1.3.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=1.14->ever-beta->geoai-py) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=1.14->ever-beta->geoai-py) (1.76.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=1.14->ever-beta->geoai-py) (3.10)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=1.14->ever-beta->geoai-py) (5.29.5)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=1.14->ever-beta->geoai-py) (0.7.2)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.12/dist-packages (from tyro>=0.9->opera-utils->leafmap[raster]) (13.9.4)
# Requirement already satisfied: shtab>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from tyro>=0.9->opera-utils->leafmap[raster]) (1.7.2)
# Requirement already satisfied: typeguard>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from tyro>=0.9->opera-utils->leafmap[raster]) (4.4.4)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.12/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->leafmap[raster]) (6.5.7)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown->leafmap[raster]) (2.8)
# Requirement already satisfied: cachelib>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from Flask-Caching->localtileserver>=0.10.6->leafmap[raster]) (0.13.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.12/dist-packages (from geopy->contextily->geoai-py) (2.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prettytable->ever-beta->geoai-py) (0.2.14)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown->leafmap[raster]) (1.7.1)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.12/dist-packages (from rio-tiler->localtileserver>=0.10.6->leafmap[raster]) (5.5.2)
# Requirement already satisfied: color-operations in /usr/local/lib/python3.12/dist-packages (from rio-tiler->localtileserver>=0.10.6->leafmap[raster]) (0.2.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.12/dist-packages (from rio-tiler->localtileserver>=0.10.6->leafmap[raster]) (0.28.1)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.12/dist-packages (from rio-tiler->localtileserver>=0.10.6->leafmap[raster]) (2.14.1)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.12/dist-packages (from server-thread->localtileserver>=0.10.6->leafmap[raster]) (0.38.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->ever-beta->geoai-py) (3.1.45)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->ever-beta->geoai-py) (2.43.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio>=3.1.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi>=21.1->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (25.1.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb->ever-beta->geoai-py) (4.0.12)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->leafmap[raster]) (0.8.5)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema->flask-restx>=1.3.0->localtileserver>=0.10.6->leafmap[raster]) (2025.9.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema->flask-restx>=1.3.0->localtileserver>=0.10.6->leafmap[raster]) (0.28.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->leafmap[raster]) (0.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (4.0.0)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (0.1.1)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (6.3.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat>=5.3.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (2.21.2)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap[raster]) (1.3.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->leafmap[raster]) (0.7.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=11.1.0->tyro>=0.9->opera-utils->leafmap[raster]) (4.0.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx->rio-tiler->localtileserver>=0.10.6->leafmap[raster]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx->rio-tiler->localtileserver>=0.10.6->leafmap[raster]) (0.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (1.4.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->ever-beta->geoai-py) (5.0.2)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (25.10.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.9->opera-utils->leafmap[raster]) (0.1.2)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap[raster]) (0.2.4)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (2.23)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (1.4.0)

# %% [markdown]
# ### Import libraries
#
# Import the necessary libraries for this workshop.

# %%
import leafmap

# %% [markdown]
# ## Creating interactive maps
#
# Let's create an interactive map using the `ipyleaflet` plotting backend. The [`leafmap.Map`](https://leafmap.org/leafmap/#leafmap.leafmap.m) class inherits the [`ipyleaflet.Map`](https://ipyleaflet.readthedocs.io/en/latest/map_and_basemaps/map.html) class. Therefore, you can use the same syntax to create an interactive map as you would with `ipyleaflet.Map`.

# %%
m = leafmap.Map()

# %% [markdown]
# To display it in a Jupyter notebook, simply ask for the object representation:

# %%
m
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %% [markdown]
# To customize the map, you can specify various keyword arguments, such as `center` ([lat, lon]), `zoom`, `width`, and `height`. The default `width` is `100%`, which takes up the entire cell width of the Jupyter notebook. The `height` argument accepts a number or a string. If a number is provided, it represents the height of the map in pixels. If a string is provided, the string must be in the format of a number followed by `px`, e.g., `600px`.

# %%
m = leafmap.Map(center=[40, -100], zoom=4, height="600px")
m
# Out:
# Map(center=[40, -100], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…

# %% [markdown]
# ### Adding basemaps
#
# There are several ways to add basemaps to a map. You can specify the basemap to use in the `basemap` keyword argument when creating the map. Alternatively, you can add basemap layers to the map using the `add_basemap` method. leafmap has hundreds of built-in basemaps available that can be easily added to the map with only one line of code.
#
# Create a map by specifying the basemap to use as follows. For example, the `Esri.WorldImagery` basemap represents the Esri world imagery basemap.

# %%
m = leafmap.Map(basemap="Esri.WorldImagery")
m
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %% [markdown]
# You can add as many basemaps as you like to the map. For example, the following code adds the `OpenTopoMap` basemap to the map above:

# %%
m.add_basemap("OpenTopoMap")
# Out:
# OpenTopoMap has been already added before.

# %% [markdown]
# You can also add an XYZ tile layer to the map.

# %%
basemap_url = "https://mt1.google.com/vt/lyrs=y&x={x}&y={y}&z={z}"
m.add_tile_layer(basemap_url, name="Hybrid", attribution="Google")

# %% [markdown]
# You can also change basemaps interactively using the basemap GUI.

# %%
m = leafmap.Map()
m.add_basemap_gui()
m
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %% [markdown]
# ## Visualizing Drone Imagery from D2S
#
# The Data to Science (D2S) platform (https://ps2.d2s.org) hosts a large collection of drone imagery that can be accessed through the D2S API (https://py.d2s.org). To visualize drone imagery from D2S, you need to [sign up](https://ps2.d2s.org/auth/register) for a free account on the D2S platform and obtain an API key.

# %% [markdown]
# ### Authenticate with D2S Platform
#
# Connect to your D2S workspace using your credentials. The workshop provides a demo account for testing.

# %%
import os
from datetime import date
from d2spy.workspace import Workspace

# %%
if os.environ.get("D2S_EMAIL") is None:
    os.environ["D2S_EMAIL"] = "blamichh@my.tnstate.edu"  # Replace with your email address

# %%
# Connect to D2S platform and authenticate
d2s_url = "https://ps2.d2s.org"
workspace = Workspace.connect(d2s_url)  # This will prompt for password
api_key = workspace.api_key  # Get API key for data access
# Out:
# Enter your D2S password:··········

# %%
os.environ["D2S_API_KEY"] = api_key
os.environ["TITILER_ENDPOINT"] = "https://tt.d2s.org"

# %% [markdown]
# ### Choose a project to work with
#
# The Workspace `get_projects` method will retrieve a collection of the projects your account can currently access on the D2S instance.

# %%
# Get list of all your projects
projects = workspace.get_projects()
for project in projects:
    print(project)
# Out:
# Project(title='Boundary', description='Test', start_date=datetime.date(2025, 11, 1), end_date=datetime.date(2025, 11, 9))
# Project(title='Test2', description='Tets', start_date=datetime.date(2022, 6, 4), end_date=datetime.date(2022, 6, 22))
# Project(title='Test', description='This is session file', start_date=datetime.date(2022, 6, 4), end_date=datetime.date(2023, 6, 23))

# %% [markdown]
# The `projects` variable is a `ProjectCollection`. The collection can be filtered by either the project descriptions or titles using the methods `filter_by_title` or `filter_by_name`.

# %%
# Example of creating new collection of only projects with the keyword "Citrus Orchard" in the title
filtered_projects = projects.filter_by_title("Test2")
print(filtered_projects)
# Out:
# ProjectCollection([Project(title='Test2', description='Tets', start_date=datetime.date(2022, 6, 4), end_date=datetime.date(2022, 6, 22))])

# %% [markdown]
# Now you can choose a specific project to work with. In this case, the filtered projects returned only one project, so we will use that project.

# %%
project = filtered_projects[0]

# %% [markdown]
# ### Get the project boundary

# %% [markdown]
# `get_project_boundary` method of the `Project` class will retrieve a GeoJSON object of the project boundary.

# %%
# Get project boundary as Python dictionary in GeoJSON structure
project_boundary = project.get_project_boundary()
project_boundary
# Out:
# {'type': 'Feature',
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[-86.944416727, 41.444049613],
#     [-86.943901782, 41.444048855],
#     [-86.943901955, 41.44384725],
#     [-86.944418248, 41.443849532],
#     [-86.944418248, 41.443849532],
#     [-86.944416727, 41.444049613]]]},
#  'properties': {'id': 'c0648a54-9744-4d99-9106-272e736a4d45',
#   'center_x': -86.94415935300185,
#   'center_y': 41.44394876758631}}

# %% [markdown]
# ### Get project flights
#
# The `Project` `get_flights` method will retrieve a list of flights associated with the project.

# %%
# Get list of all flights for a project
flights = project.get_flights()
# Print first flight object (if one exists)
for flight in flights:
    print(flight)
# Out:
# Flight(acquisition_date='2022-06-14', name='DEM', altitude=120.0, side_overlap=60.0, forward_overlap=75.0, sensor='RGB', platform='M300')
# Flight(acquisition_date='2022-06-13', name='RGB', altitude=120.0, side_overlap=60.0, forward_overlap=75.0, sensor='RGB', platform='M300')
# Flight(acquisition_date='2022-06-14', name='DSM', altitude=120.0, side_overlap=60.0, forward_overlap=75.0, sensor='RGB', platform='Phantom_4')
# Flight(acquisition_date='2022-06-15', name='Ortho', altitude=120.0, side_overlap=60.0, forward_overlap=75.0, sensor='RGB', platform='Phantom_4')

# %% [markdown]
# ### Filter flights by date
#
# The `flights` variable is a `FlightCollection`. The collection can be filtered by the acquisition date using the method `filter_by_date`. This method will return all flights with an acquisition date between the provided start and end dates.

# %%
# Example of creating new collection of only flights from June 2022
filtered_flights = flights.filter_by_date(
    start_date=date(2022, 6, 1), end_date=date(2022, 7, 1)
)
for flight in filtered_flights:
    print(flight)
# Out:
# Flight(acquisition_date='2022-06-14', name='DEM', altitude=120.0, side_overlap=60.0, forward_overlap=75.0, sensor='RGB', platform='M300')
# Flight(acquisition_date='2022-06-13', name='RGB', altitude=120.0, side_overlap=60.0, forward_overlap=75.0, sensor='RGB', platform='M300')
# Flight(acquisition_date='2022-06-14', name='DSM', altitude=120.0, side_overlap=60.0, forward_overlap=75.0, sensor='RGB', platform='Phantom_4')
# Flight(acquisition_date='2022-06-15', name='Ortho', altitude=120.0, side_overlap=60.0, forward_overlap=75.0, sensor='RGB', platform='Phantom_4')

# %% [markdown]
# Now, we can choose a flight from the filtered flight. Let's choose the flight on June 9, 2022.

# %%
flight = filtered_flights[0]
flight
# Out:
# Flight(acquisition_date='2022-06-14', name='DEM', altitude=120.0, side_overlap=60.0, forward_overlap=75.0, sensor='RGB', platform='M300')

# %% [markdown]
# ### Get data products
#
# The Flight `get_data_products` method will retrieve a list of data products associated with the flight.

# %%
# Get list of data products from a flight
data_products = flight.get_data_products()

for data_product in data_products:
    print(data_product)
# Out:
# DataProduct(data_type='dem', filepath='/static/projects/47d170d9-40e6-401f-a7fb-3958e980e725/flights/62e42377-8f35-4796-8a18-67cf769e9528/data_products/07f2de5e-410e-494b-95e2-e4365d6d489b/e58ed986-b02c-4724-a0ed-c12dcb2b2c24.tif', original_filename='220725_ortho_multispectral.tif', is_active=True, public=False, stac_properties={'raster': [{'data_type': 'uint16', 'stats': {'minimum': 0.0, 'maximum': 65535.0, 'mean': 22049.059, 'stddev': 7351.42}}, {'data_type': 'uint16', 'stats': {'minimum': 0.0, 'maximum': 65535.0, 'mean': 19842.593, 'stddev': 7724.981}}, {'data_type': 'uint16', 'stats': {'minimum': 0.0, 'maximum': 65535.0, 'mean': 13980.419, 'stddev': 7933.603}}, {'data_type': 'uint16', 'stats': {'minimum': 704.0, 'maximum': 65253.0, 'mean': 27866.417, 'stddev': 11751.38}}, {'data_type': 'uint16', 'stats': {'minimum': 2912.0, 'maximum': 60675.0, 'mean': 31316.146, 'stddev': 13710.101}}, {'data_type': 'uint16', 'stats': {'minimum': 65535.0, 'maximum': 65535.0, 'mean': 65535.0, 'stddev': 0.0}}], 'eo': [{'name': 'b1', 'description': 'Gray'}, {'name': 'b2', 'description': 'Undefined'}, {'name': 'b3', 'description': 'Undefined'}, {'name': 'b4', 'description': 'Undefined'}, {'name': 'b5', 'description': 'Undefined'}, {'name': 'b6', 'description': 'Undefined'}]}, status='SUCCESS', url='https://ps2.d2s.org/static/projects/47d170d9-40e6-401f-a7fb-3958e980e725/flights/62e42377-8f35-4796-8a18-67cf769e9528/data_products/07f2de5e-410e-494b-95e2-e4365d6d489b/e58ed986-b02c-4724-a0ed-c12dcb2b2c24.tif', bbox=[-86.94440662813535, 41.4438586425377, -86.94391572089675, 41.444039102653946], crs={'epsg': 32616, 'unit': 'metre'}, resolution={'x': 0.02039547263681124, 'y': 0.02039541284364784, 'unit': 'metre'})
# DataProduct(data_type='dem', filepath='/static/projects/47d170d9-40e6-401f-a7fb-3958e980e725/flights/62e42377-8f35-4796-8a18-67cf769e9528/data_products/65e6ddab-e7f8-4ff3-ad1d-8f323d78929c/1cd2b578-1b50-45d1-be96-5cf0c763115c.tif', original_filename='220725_ortho_rgb.tif', is_active=True, public=False, stac_properties={'raster': [{'data_type': 'uint8', 'stats': {'minimum': 0.0, 'maximum': 255.0, 'mean': 83.732, 'stddev': 47.98}}, {'data_type': 'uint8', 'stats': {'minimum': 0.0, 'maximum': 255.0, 'mean': 100.07, 'stddev': 48.564}}, {'data_type': 'uint8', 'stats': {'minimum': 0.0, 'maximum': 255.0, 'mean': 69.387, 'stddev': 45.407}}, {'data_type': 'uint8', 'stats': {'minimum': 255.0, 'maximum': 255.0, 'mean': 255.0, 'stddev': 0.0}}], 'eo': [{'name': 'b1', 'description': 'Red'}, {'name': 'b2', 'description': 'Green'}, {'name': 'b3', 'description': 'Blue'}, {'name': 'b4', 'description': 'Alpha'}]}, status='SUCCESS', url='https://ps2.d2s.org/static/projects/47d170d9-40e6-401f-a7fb-3958e980e725/flights/62e42377-8f35-4796-8a18-67cf769e9528/data_products/65e6ddab-e7f8-4ff3-ad1d-8f323d78929c/1cd2b578-1b50-45d1-be96-5cf0c763115c.tif', bbox=[-86.94440643181011, 41.44385864240406, -86.94391544683339, 41.44403901608671], crs={'epsg': 32616, 'unit': 'metre'}, resolution={'x': 0.004807292765858634, 'y': 0.00480728365386872, 'unit': 'metre'})

# %% [markdown]
# The `data_products` variable is a `DataProductCollection`. The collection can be filtered by data type using the method `filter_by_data_type`. This method will return all data products that match the requested data type.

# %%
# Example of creating new collection of data products with the "ortho" data type
ortho_data_products = data_products.filter_by_data_type("ortho")
print(ortho_data_products)
# Out:
# DataProductCollection([])

# %% [markdown]
# ### Visualize ortho imagery
#
# Now we can grab the ortho URL to display it using leafmap.

# %%
m = leafmap.Map(center=[26.165966, -97.955640], zoom=16)
m.add_basemap("HYBRID", show=False)
ortho_data = ortho_data_products[0]
ortho_url_202206 = ortho_data.url
ortho_url_202206 = leafmap.d2s_tile(ortho_url_202206)
m.add_cog_layer(ortho_url_202206, name="Orhtorgb")
m
# Out:
# Map(center=[26.165966, -97.95564], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title',…

# %% [markdown]
# ### Visualize DSM
#
# Similarly, you can visualize the Digital Surface Model (DSM) from D2S using the code below.

# %%
# Example of creating new collection of data products with the "dsm" data type
dsm_data_products = data_products.filter_by_data_type("dsm")
print(dsm_data_products)
# Out:
# DataProductCollection([])

# %%
dsm_data = dsm_data_products[0]
dsm_url_202206 = dsm_data.url
dsm_url_202206 = leafmap.d2s_tile(dsm_url_202206)
m.add_cog_layer(dsm_url_202206, colormap_name="terrain", name="Multi")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-1501252378.py in <cell line: 0>()
# ----> 1 dsm_data = dsm_data_products[0]
#       2 dsm_url_202206 = dsm_data.url
#       3 dsm_url_202206 = leafmap.d2s_tile(dsm_url_202206)
#       4 m.add_cog_layer(dsm_url_202206, colormap_name="terrain", name="Multi")
#
# /usr/local/lib/python3.12/dist-packages/d2spy/models/data_product_collection.py in __getitem__(self, index)
#      11
#      12     def __getitem__(self, index: int) -> DataProduct:
# ---> 13         return self.collection[int(index)]
#      14
#      15     def __len__(self) -> int:
#
# IndexError: list index out of range

# %%
leafmap.cog_stats(dsm_url_202206)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1561622462.py in <cell line: 0>()
# ----> 1 leafmap.cog_stats(dsm_url_202206)
#
# NameError: name 'dsm_url_202206' is not defined

# %% [markdown]
# Add a colorbar to the map.

# %%
m.add_colormap(cmap="terrain", vmin=3, vmax=33, label="Elevation (m)")
m
# Out:
# Map(center=[26.165966, -97.95564], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title',…

# %% [markdown]
# ### Visualize CHM
#
# Similarly, you can visualize the Canopy Height Model (CHM) from D2S using the code below.

# %%
# Example of creating new collection of data products with the "chm" data type
chm_data_products = data_products.filter_by_data_type("chm")
print(chm_data_products)
# Out:
# DataProductCollection([])

# %%
chm_data = chm_data_products[0]
chm_url_202206 = chm_data.url
chm_url_202206 = leafmap.d2s_tile(chm_url_202206)
m.add_cog_layer(chm_url_202206, colormap_name="jet", name="CHM 202206")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-247017838.py in <cell line: 0>()
# ----> 1 chm_data = chm_data_products[0]
#       2 chm_url_202206 = chm_data.url
#       3 chm_url_202206 = leafmap.d2s_tile(chm_url_202206)
#       4 m.add_cog_layer(chm_url_202206, colormap_name="jet", name="CHM 202206")
#
# /usr/local/lib/python3.12/dist-packages/d2spy/models/data_product_collection.py in __getitem__(self, index)
#      11
#      12     def __getitem__(self, index: int) -> DataProduct:
# ---> 13         return self.collection[int(index)]
#      14
#      15     def __len__(self) -> int:
#
# IndexError: list index out of range

# %%
leafmap.cog_stats(chm_url_202206)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1220156343.py in <cell line: 0>()
# ----> 1 leafmap.cog_stats(chm_url_202206)
#
# NameError: name 'chm_url_202206' is not defined

# %%
m.add_colormap(cmap="jet", vmin=0, vmax=13, label="Elevation (m)")
m
# Out:
# Map(bottom=14249370.0, center=[26.164239656950357, -97.95594155788423], controls=(ZoomControl(options=['positi…

# %% [markdown]
# Add the project boundary to the map.

# %%
m.add_geojson(project_boundary, layer_name="Project Boundary")

# %% [markdown]
# Add tree boundaries to the map.

# %%
map_layers = project.get_map_layers()
tree_boundaries = map_layers[0]

# %%
gdf = leafmap.geojson_to_gdf(tree_boundaries)
gdf.to_file("tree_boundaries.geojson")

# %%
m.add_geojson(tree_boundaries, layer_name="Tree Boundaries")

# %% [markdown]
# ### Get another flight
#
# Retrieve the Ortho data product for the December 2022 flight.

# %%
filtered_flights = flights.filter_by_date(
    start_date=date(2022, 12, 1), end_date=date(2022, 12, 31)
)
for flight in filtered_flights:
    print(flight)

# %%
flight_202212 = filtered_flights[0]
data_products = flight_202212.get_data_products()
ortho_data_products = data_products.filter_by_data_type("ortho")
ortho_data = ortho_data_products[0]
ortho_url_202212 = ortho_data.url
ortho_url_202212 = leafmap.d2s_tile(ortho_url_202212)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-3314898022.py in <cell line: 0>()
# ----> 1 flight_202212 = filtered_flights[0]
#       2 data_products = flight_202212.get_data_products()
#       3 ortho_data_products = data_products.filter_by_data_type("ortho")
#       4 ortho_data = ortho_data_products[0]
#       5 ortho_url_202212 = ortho_data.url
#
# /usr/local/lib/python3.12/dist-packages/d2spy/models/flight_collection.py in __getitem__(self, index)
#      13
#      14     def __getitem__(self, index: int) -> Flight:
# ---> 15         return self.collection[int(index)]
#      16
#      17     def __len__(self) -> int:
#
# IndexError: list index out of range

# %% [markdown]
# ### Compare two ortho images
#
# Create a split map for comparing the June 2022 and December 2022 ortho images.

# %%
from ipyleaflet import TileLayer

m = leafmap.Map()
left_layer = TileLayer(
    url=leafmap.cog_tile(ortho_url_202206), max_zoom=30, name="2022-06 Ortho"
)
right_layer = TileLayer(
    url=leafmap.cog_tile(ortho_url_202212), max_zoom=30, name="2022-12 Ortho"
)
m.split_map(left_layer, right_layer, left_label="2022-06", right_label="2022-12")
m.set_center(-97.955281, 26.165595, 18)
m
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-919959125.py in <cell line: 0>()
#       3 m = leafmap.Map()
#       4 left_layer = TileLayer(
# ----> 5     url=leafmap.cog_tile(ortho_url_202206), max_zoom=30, name="2022-06 Ortho"
#       6 )
#       7 right_layer = TileLayer(
#
# NameError: name 'ortho_url_202206' is not defined

# %% [markdown]
# ## Download and Prepare Data for Analysis
#
# In this section, we'll download a subset of the drone imagery from D2S and prepare it for machine learning model training and inference.

# %%
m = leafmap.Map()
#m.add_cog_layer(ortho_url_202206, name="Orhtorgb")
m.add_cog_layer(name="Orhtorgb")
m
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3456778323.py in <cell line: 0>()
#       1 m = leafmap.Map()
#       2 #m.add_cog_layer(ortho_url_202206, name="Orhtorgb")
# ----> 3 m.add_cog_layer(name="Orhtorgb")
#       4 m
#
# TypeError: Map.add_cog_layer() missing 1 required positional argument: 'url'

# %% [markdown]
# ### Define Area of Interest (AOI)
#
# Draw an area of interest (AOI) on the map using the drawing tools, or use the default bounding box provided below. This AOI will be used to clip the imagery for analysis.

# %%
# Define bounding box for the area of interest
# Format: [min_lon, min_lat, max_lon, max_lat]
if m.user_roi is not None:
    bbox = m.user_roi_bounds()  # Use drawn ROI if available
else:
    bbox = [-97.956252, 26.165315, -97.954992, 26.165883]  # Default ROI

# %%
ortho_image_202206 = "ortho_image_202206.tif"
if not os.path.exists(ortho_image_202206):
    leafmap.download_file(ortho_url_202206, output=ortho_image_202206)

# %%
ortho_image_202212 = "ortho_image_202212.tif"
if not os.path.exists(ortho_image_202212):
    leafmap.download_file(ortho_url_202212, output=ortho_image_202212)

# %% [markdown]
# Draw an area of interest (AOI) on the map. If an AOI is not provided, a default AOI will be used.

# %%
if m.user_roi is not None:
    bbox = m.user_roi_bounds()
else:
    bbox = [-97.956252, 26.165315, -97.954992, 26.165883]

# %%
gdf = leafmap.bbox_to_gdf(bbox)
m.add_gdf(gdf, layer_name="AOI", info_mode=None)

# %%
ortho_image_10cm = "ortho_image_202206_10cm.tif"
chm_image = "chm_202206.tif"

# %%
clipped_ortho_data_10cm = leafmap.clip_raster(
    ortho_image_202206,
    geometry=bbox,
    geom_crs="EPSG:4326",
    bands=[1, 2, 3],
    resolution=0.1,
    output=ortho_image_10cm,
)

# %%
clipped_chm_data = leafmap.clip_raster(
    chm_url_202206,
    geometry=bbox,
    geom_crs="EPSG:4326",
    match_raster=clipped_ortho_data_10cm,
    output=chm_image,
)

# %%
m = leafmap.Map()
m.add_raster(ortho_image_10cm, layer_name="Ortho Image 202206")
m.add_raster(chm_image, colormap="terrain", nodata=0, layer_name="CHM 202206")
m.add_geojson(tree_boundaries, layer_name="Tree Boundaries")
m

# %% [markdown]
# ## Automated Segmentation with SAM (Segment Anything Model)
#
# SAMGeo is a Python package that applies Meta's Segment Anything Model (SAM) to geospatial data. It can automatically segment objects in drone and satellite imagery without requiring training data.
#
# ### Initialize SAM2 Model
#
# First, we'll initialize the SAM2 model with parameters that control segmentation quality and detail.

# %%
from samgeo import SamGeo, SamGeo2

# %%
# Initialize SAM2 model for automatic segmentation
sam2 = SamGeo2(
    model_id="sam2-hiera-large",  # Use the large hierarchical SAM2 model
    automatic=True,  # Enable automatic mask generation mode
    stability_score_thresh=0.9,  # Higher = fewer, more stable masks
    stability_score_offset=0.7,  # Adjusts stability calculation
)

# %% [markdown]
# ### Generate Segmentation Masks
#
# Run SAM2 on the ortho imagery to automatically detect and segment all objects. This process may take a few minutes depending on image size and computational resources.

# %%
# Generate masks for all objects detected in the image
sam2.generate(ortho_image_10cm)

# %%
# Save the generated masks as a GeoTIFF file
# Each unique object gets a unique integer ID
sam2.save_masks(output="masks.tif")

# %%
sam2.show_masks(cmap="binary_r")

# %% [markdown]
# ![image](https://github.com/user-attachments/assets/fec9ad33-338e-4d1f-95e5-5f7b58e15edb)

# %%
sam2.show_masks(cmap="jet")

# %% [markdown]
# ![image](https://github.com/user-attachments/assets/32036cec-96a2-46c7-b948-a859925d8600)

# %% [markdown]
# Show the object annotations (objects with random color) on the map.

# %%
sam2.show_anns(axis="off", alpha=0.7, output="annotations.tif")

# %% [markdown]
# ![image](https://github.com/user-attachments/assets/8a05f797-5a08-4bb2-b6b3-ee8f82d8bd32)

# %% [markdown]
# ### Compare Original and Segmented Images
#
# Use an interactive slider to compare the original drone imagery with the SAM segmentation results.

# %%
leafmap.image_comparison(
    ortho_image_10cm,
    "annotations.tif",
    label1="Drone Imagery",
    label2="Image Segmentation",
)

# %% [markdown]
# Add segmentation result to the map.

# %%
m = leafmap.Map()
m.add_raster(ortho_image_10cm, layer_name="Ortho Imagery 202206")
m.add_raster("masks.tif", colormap="jet", layer_name="Masks", nodata=0, opacity=0.7)
m

# %% [markdown]
# Convert the object masks to vector format, such as GeoPackage, Shapefile, or GeoJSON.

# %%
sam2.raster_to_vector("masks.tif", "masks.gpkg")

# %%
m.add_vector("masks.gpkg", layer_name="Objects")

# %% [markdown]
# ### Automatic mask generation options
#
# There are several tunable parameters in automatic mask generation that control how densely points are sampled and what the thresholds are for removing low quality or duplicate masks. Additionally, generation can be automatically run on crops of the image to get improved performance on smaller objects, and post-processing can remove stray pixels and holes. Here is an example configuration that samples more masks:

# %%
sam2 = SamGeo2(
    model_id="sam2-hiera-large",
    apply_postprocessing=False,
    points_per_side=64,
    points_per_batch=128,
    pred_iou_thresh=0.7,
    stability_score_thresh=0.92,
    stability_score_offset=0.7,
    crop_n_layers=1,
    box_nms_thresh=0.7,
    crop_n_points_downscale_factor=2,
    min_mask_region_area=25,
    use_m2m=True,
)

# %%
sam2.generate(ortho_image_10cm, output="masks2.tif")

# %%
sam2.show_masks(cmap="jet")

# %% [markdown]
# ![image](https://github.com/user-attachments/assets/ff07bff9-f0d1-41c6-a641-ce9f4734fd61)

# %%
sam2.show_anns(axis="off", alpha=0.7, output="annotations2.tif")

# %% [markdown]
# ![image](https://github.com/user-attachments/assets/1e1df62c-ec44-4c5e-aa5a-4025d078ff6b)

# %%
leafmap.image_comparison(
    ortho_image_10cm,
    "annotations2.tif",
    label1="Image",
    label2="Image Segmentation",
)

# %% [markdown]
# Remove small objects.

# %%
da, gdf = sam2.region_groups(
    "masks2.tif",
    connectivity=1,
    min_size=10,
    max_size=2000,
    intensity_image="chm_202206.tif",
    out_image="objects.tif",
    out_csv="objects.csv",
    out_vector="objects.gpkg",
)

# %%
m = leafmap.Map()
m.add_raster(ortho_image_10cm, layer_name="Ortho Imagery 202206")
m.add_vector("objects.gpkg", layer_name="Objects")
m

# %% [markdown]
# ### Using box prompts
#
# Restart the Runtime to avoid the VRAM allocation issue.

# %%
import leafmap
from samgeo import SamGeo

# %%
ortho_image_10cm = "ortho_image_202206_10cm.tif"
geojson = "tree_boundaries.geojson"

# %%
gdf = leafmap.geojson_to_gdf(geojson)
gdf.head()

# %%
m = leafmap.Map()
m.add_raster(ortho_image_10cm, layer_name="image")
style = {
    "color": "#ffff00",
    "weight": 2,
    "fillColor": "#7c4185",
    "fillOpacity": 0,
}
m.add_vector(geojson, style=style, zoom_to_layer=True, layer_name="Bounding boxes")
m

# %%
sam = SamGeo(
    model_type="vit_h",
    automatic=False,
    sam_kwargs=None,
)

# %%
sam.set_image(ortho_image_10cm)

# %%
sam.predict(
    boxes=geojson, point_crs="EPSG:4326", output="tree_masks.tif", dtype="uint16"
)

# %%
m.add_raster(
    "tree_masks.tif", cmap="jet", nodata=0, opacity=0.5, layer_name="Tree masks"
)
m

# %% [markdown]
# ![image](https://github.com/user-attachments/assets/0a9b794d-cf94-4e5c-9134-8799e67d338c)

# %% [markdown]
# ## Training a Deep Learning Model for Tree Segmentation
#
# While SAM provides zero-shot segmentation, sometimes you need a custom model trained on your specific data. In this section, we'll train a U-Net model to segment tree canopies using labeled training data.
#
# ### Why Train a Custom Model?
#
# - **Domain-specific accuracy**: Custom models learn features specific to your task (e.g., tree canopies vs. general objects)
# - **Consistency**: Produces consistent results across multiple images from the same sensor
# - **Speed**: Once trained, inference is faster than running SAM on large datasets
# - **Control**: You can tune the model to prioritize precision or recall based on your needs

# %%
import geoai
import leafmap

# %% [markdown]
# ### Prepare Training and Testing Datasets
#
# Deep learning models require labeled training data. We'll use tree boundary vectors from D2S to create training labels, then split our data into training and testing sets.

# %%
m = leafmap.Map()
m.add_raster("ortho_image_202206.tif", layer_name="Ortho Imagery 202206")
m.add_vector("tree_boundaries.geojson", layer_name="Tree Boundaries")
m

# %%
# Define separate regions for training and testing
# Training: Use June 2022 imagery with tree boundaries
# Testing: Use December 2022 imagery to test model generalization
bbox = [-97.956252, 26.165315, -97.954992, 26.165883]

# %%
ortho_image_202206 = "ortho_image_202206.tif"
ortho_image_202212 = "ortho_image_202212.tif"
train_raster_path = "ortho_image_202206_train.tif"
test_raster_path = "ortho_image_202212_test.tif"
train_vector_path = "tree_boundaries.geojson"

# %%
# Clip training imagery to the training bbox
# Resolution: 2cm (0.02m) provides good detail for tree segmentation
train_image_array = leafmap.clip_raster(
    ortho_image_202206,
    geometry=bbox,
    geom_crs="EPSG:4326",
    resolution=0.02,  # 2cm resolution
    output=train_raster_path,
)

# %%
test_image_array = leafmap.clip_raster(
    ortho_image_202212,
    geometry=bbox,
    geom_crs="EPSG:4326",
    resolution=0.02,
    output=test_raster_path,
)

# %% [markdown]
# ### Generate Training Tiles
#
# Neural networks typically work with fixed-size inputs. We'll split the large training image into 512x512 pixel tiles with 256-pixel overlap to ensure complete coverage.

# %%
# Create training tiles from the imagery and tree boundaries
# This will generate image/label pairs for U-Net training
out_folder = "trees"
tiles = geoai.export_geotiff_tiles(
    in_raster=train_raster_path,  # Input imagery
    out_folder=out_folder,  # Output directory
    in_class_data=train_vector_path,  # Tree boundary labels
    tile_size=512,  # Size of each tile in pixels
    stride=256,  # Step between tiles (50% overlap)
    buffer_radius=0,  # No buffer around geometries
)

# %% [markdown]
# ### Train the U-Net Model
#
# Now we'll train a U-Net semantic segmentation model with a ResNet34 encoder (pretrained on ImageNet). This process includes:
#
# - **Architecture**: U-Net with ResNet34 backbone for feature extraction
# - **Training data**: 288 tiles split into 80% train / 20% validation
# - **Optimization**: Adam optimizer with learning rate 0.001
# - **Epochs**: 30 training epochs with best model checkpointing
# - **Metrics**: IoU (Intersection over Union), F1-score, Precision, and Recall
#
# Training on a GPU (T4 or better) typically takes 5-10 minutes for this dataset.

# %%
# Train U-Net model
geoai.train_segmentation_model(
    images_dir=f"{out_folder}/images",
    labels_dir=f"{out_folder}/labels",
    output_dir=f"{out_folder}/unet_models",
    architecture="unet",
    encoder_name="resnet34",
    encoder_weights="imagenet",
    num_channels=4,
    num_classes=2,  # background and trees
    batch_size=8,
    num_epochs=10,
    learning_rate=0.001,
    val_split=0.2,
    verbose=True,
)

# %%
geoai.plot_performance_metrics(
    history_path=f"{out_folder}/unet_models/training_history.pth",
    figsize=(15, 5),
    verbose=True,
)

# %% [markdown]
# ![metrics](https://github.com/user-attachments/assets/17f13951-1805-43c9-8eac-0c74acd303cc)

# %% [markdown]
# ```text
# === Performance Metrics Summary ===
# IoU     - Best: 0.9454 | Final: 0.9420
# F1      - Best: 0.9718 | Final: 0.9700
# Precision - Best: 0.9715 | Final: 0.9700
# Recall  - Best: 0.9722 | Final: 0.9702
# Val Loss - Best: 0.0746 | Final: 0.0829
# ===================================
# ```

# %%
model_path = f"{out_folder}/unet_models/best_model.pth"
masks_path = "ortho_image_202212_masks.tif"
probability_path = "probabilities.tif"

# %% [markdown]
# ### Apply Model to Test Imagery
#
# Use the trained model to predict tree canopies on the December 2022 test imagery. We'll save both:
# - **Classification mask**: Final tree/background predictions
# - **Probability map**: Per-pixel confidence scores for each class

# %%
# Run inference on the test image using the trained model
geoai.semantic_segmentation(
    input_path=test_raster_path,  # Input test imagery
    output_path=masks_path,  # Output classification mask
    model_path=model_path,  # Path to trained model weights
    architecture="unet",  # Same architecture as training
    encoder_name="resnet34",  # Same encoder as training
    num_channels=4,  # RGB + NIR bands
    num_classes=2,  # Background (0) and trees (1)
    window_size=512,  # Process in 512x512 windows
    overlap=256,  # 50% overlap for smooth boundaries
    batch_size=8,  # Process 8 windows at a time
    probability_threshold=0.5,  # Confidence threshold for classification
    probability_path=probability_path,  # Save probability scores
)

# %% [markdown]
# ### Visualize Results
#
# Display the test imagery, predicted segmentation masks, and probability maps on an interactive map. The probability layer shows the model's confidence for each pixel (higher values = more confident).

# %%
# Create an interactive map to visualize the results
m = leafmap.Map()

# Add the original test imagery as the base layer
m.add_raster(test_raster_path, layer_name="Ortho Imagery 202212")

# Add the segmentation mask (hidden by default)
m.add_raster(
    masks_path,
    colormap="jet",
    layer_name="Segmentation",
    nodata=0,
    visible=False,  # Hidden by default, can toggle on
)

# Add the probability map showing model confidence
# Band 2 contains the probability for class 1 (trees)
m.add_raster(
    probability_path,
    indexes=[2],  # Class 1 (tree) probability
    colormap="jet",  # Color scale: blue (low) to red (high confidence)
    opacity=0.5,  # Semi-transparent overlay
    layer_name="Tree Probability",
    nodata=0,
)

m

# %% [markdown]
# ![image](https://github.com/user-attachments/assets/8bd2af2b-dd13-48c1-a4f1-c6bbe0faff00)

# %% [markdown]
# ## Summary and Next Steps
#
# In this workshop, you learned how to:
#
# 1. **Access and visualize drone imagery** from the Data to Science (D2S) platform
# 2. **Perform zero-shot segmentation** using SAM2 for automatic object detection
# 3. **Train custom deep learning models** (U-Net) for domain-specific segmentation tasks
# 4. **Apply trained models** to new imagery and evaluate results
#
# ### Key Takeaways
#
# - **SAM2** is excellent for exploratory analysis and when you don't have training labels
# - **Custom U-Net models** provide better accuracy for specific tasks when training data is available
# - The **GeoAI package** simplifies the entire pipeline from data preparation to model deployment
# - **Leafmap** makes it easy to visualize and interact with geospatial AI results
#
# ### Next Steps
#
# - Apply these techniques to your own drone or satellite imagery
# - Experiment with different model architectures (DeepLabV3+, FPN, etc.)
# - Try transfer learning from pre-trained models on similar agricultural datasets
# - Explore temporal analysis by comparing multiple flights over time
# - Integrate with other geospatial analysis workflows (crop health, yield prediction, etc.)
#
# ### Resources
#
# - **GeoAI Documentation**: https://opengeoai.org
# - **Leafmap Documentation**: https://leafmap.org
# - **SAMGeo Documentation**: https://samgeo.gishub.org
# - **D2S website**: https://d2s.org
# - **D2S Platform**: https://ps2.d2s.org
# - **D2S STAC**: https://stac.d2s.org
# - **D2S GitHub**: https://github.com/gdslab/data-to-science
#
# ### Questions?
#
# Feel free to reach out to the GeoAI community on GitHub.
